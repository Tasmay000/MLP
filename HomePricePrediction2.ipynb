# %% [markdown]
# <a href="https://colab.research.google.com/github/Tasmay000/MLP/blob/main/HomePricePrediction2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv("homepricesMulti.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
# To handle null values
medians_bedrooms =math.floor(df.bedrooms.median())
df.bedrooms = df.bedrooms.fillna(medians_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
# To handle null values
medians_bedrooms =math.floor(df.bedrooms.median())
df.bedrooms = df.bedrooms.fillna(medians_bedrooms)
df
reg = LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
reg.coef_ # values of m
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_ # value of b
# Out:
# 221323.00186540396

# %%
medians_bedrooms =math.floor(df.bedrooms.median())
df.bedrooms = df.bedrooms.fillna(medians_bedrooms)
df
reg = LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
reg.predict([[3000,4,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([634907.2584604])

# %%
plt.scatter(df.area,df.price,marker = '+',color = 'red')
plt.xlabel("ABAge")
plt.ylabel("Prices")
plt.show()
